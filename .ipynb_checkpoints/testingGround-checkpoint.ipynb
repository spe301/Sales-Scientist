# %%
import pandas as pd
from fullcontact import FullContactClient
import numpy as np
from imblearn.over_sampling import SMOTENC
from helpers import Data
from urllib.request import urlopen, Request
import mysql.connector
from getpass import getpass
from mysql.connector import connect
from bs4 import BeautifulSoup
import re

df = pd.read_csv(r'C:\Users\aacjp\Spencer\datasets\MockHyros.csv')
df1 = pd.read_csv(r'C:\Users\aacjp\Spencer\datasets\HyrosNumerical.csv')
df2 = pd.read_csv(r'C:\Users\aacjp\Spencer\datasets\HyrosAugmented.csv')

# %%
def lpCopy(url, headers):
    req = Request(url=url, headers=headers) 
    print('done')
    html = urlopen(req).read()
    print('done')
    soup = BeautifulSoup(html, 'lxml')
    print('done')
    div = soup.findAll('div')
    print('done')
    p = soup.findAll('p')
    print('done')
    try:
        text = div[0].text + p[0].text
    except: 
        text = div[0].text
    print('done')
    text2 = text.replace('\n', '').replace('\'', '').replace(')', '').replace('(', '').lower()
    print('done')
    text3 = re.sub("([\(\[]).*?([\)\]])", '', text2)
    print('done')
    text4 = re.sub(r'\[(^)*\]', '', text3)
    print('done')
    text5 = text4.replace('-', '').replace('"', '').replace('!', ' ').replace('*', '').replace(':', ' ').replace('.', ' ')
    print('done')
    text6 = text5.replace('?', ' ')
    text7 = text6.replace('|', '').replace('/', '').replace(',', '').replace('...', '')
    text8 = text7.replace('\xa0', '').replace('“', '').replace('”', '').replace('…', '')
    return text8

# %%
def ctaButton(url, headers):
    req = Request(url=url, headers=headers) 
    print('done')
    html = urlopen(req).read()
    print('done')
    soup = BeautifulSoup(html, 'lxml')
    print('done')
    span = soup.findAll('span')
    print('done')
    return span[2].text.lower()

url = 'https://frankkernbook.com/optin24883998?utm_source=paid&utm_medium=paid&utm_campaign=mid-short-clips-vv&utm_content=mid-short-clips-vv'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}
ctaButton(url, headers)
# Out:
# done
# done
# done
# done
# 'send me the book'

# %% [markdown]
# The Hack: http://sangaline.com/post/advanced-web-scraping-tutorial/

# %% [markdown]
# https://platform.fullcontact.com/developers/api-keys

# %%
connection = connect(host='localhost', user='root', password='Raptor//Kona9', database='sys')
cursor = connection.cursor()

# %%
#pulling the landing pages from our database
q = 'select landing from facebook;'
cursor.execute(q)
results = cursor.fetchall()

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.3'}

# I need to inspect the holdup at results[54]
def lpContent(results, headers):
    #connection = connect(host='localhost', user='root', password='Raptor//Kona9', database='sys')
    #cursor = connection.cursor()
    copy = []
    for i in range(len(results)):
        print(i)
        url = results[i][0]
        try:
            lp = lpCopy(url, headers) + ' ' + ctaButton(url, headers)
        except:
            lp = ''
        copy.append(lp)
        #q = 'INSERT INTO facebook (lp) VALUES ({});'.format(lp)
    return pd.DataFrame(copy)

# %%
metadata = lpContent(results[:52], headers)
# Out:
# 0
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 1
# 2
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 3
# 4
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 5
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 6
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 7
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 8
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 9
# done
# done
# done
# done
# done
# 10
# 11
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 12
# 13
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 14
# 15
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 16
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 17
# 18
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 19
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 20
# 21
# 22
# 23
# 24
# 25
# 26
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 27
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 28
# 29
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 30
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 31
# 32
# 33
# 34
# 35
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 36
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 37
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 38
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 39
# 40
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 41
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 42
# 43
# 44
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 45
# 46
# 47
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 48
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# 49
# 50
# 51

# %%
metadata.columns = ['content']
metadata['content'][0]
# Out:
# 'download report now yes i am ready to get started today  we will not spam rent or sell your information    custom javascript  htmlnew book revealshow to create internet campaigns that sell   frank kernfrom the desk of frank kernla jolla ca dear friendif youd like to create internet campaigns that sell like crazy  regardless of your industry this is the most important letter youll read today ill show you why in a minute but first    a disclaimer please understand my results im sharing with you are not typical  i’m not implying you’ll duplicate them or do anything for that matter i have the benefit of practicing direct response marketing and advertising for 19 years and have an established following as a result the average person who buys any how to information gets little to no results  i’m using these references for example purposes only your results will vary and depend on many factors including but not limited to your background experience and work ethic all business entails risk as well as massive and consistent effort and action  if youre not willing to accept that please do not get this book with that said  let me jump right in and show youexactly what youre gettingthis is dramatically different from anything youve ever read because its more of a field guide to advertising for massive success than a traditional book the reason why is because theres no fluff or filler  it immediately gets down to brass tacks showing you exactly what to do how to do it and why plus its easy to read at just 75 pages you can read it in an afternoon  and youll immediately get the entire methodology i personally used to create some of the most successful internet advertising promotions in history heres just a fraction of whats inside and what it might mean for your business best news ever  your competitors are practically throwing customers at you as you read this how theyre making three deadly mistakes that can drive their customers to you in droves all you have to do is basically show up and you might dominate your marketplace in a matter of days using this one simple method  see page 3 breakthrough tactic for gaining trust with your prospects very few businesses do this and i think its around 300 times easier than the normal methods everyone else does  youll get a crystal clear understanding of this on page 54  the simple secret of the worlds highest paid speaker  and how you can reverse engineer it for your own personal gain  see page 20 plug your ears  youre being fed terrible misinformation by these come lately marketers and their shiny objects there are only three proven steps to sustainable profits and they work together in perfect synergy when applied in the right order  on page six youll get the exact 3part equation for profits that drives this entire system  youll instantly understand it so you can apply it to your business today  implement this and you might completely dominate your market    catapulting yourself your business or your brand to celebrity status and outselling your competition while theyre left scratching their heads in wonder the two things you can do immediately to increase sales and revenue without spending money on more traffic and without sending more emails to your list this sameday approach works like crazy and does not involve affiliates joint ventures or any of the usual internet marketing tricks youve heard over and over again  see page 7 steal this  theres an amazing psychological effect that makes people line up in droves to proudly spend 300% more on the same type of product their friends just bought for a fraction of the price beginning on page 9 i walk you through a presentday case study and reveal exactly how this is done why it works and the exact steps you can take to have the same mad rush effect in your business ive personally deployed this strategy in two of my businesses    successfully charging as much as 500% more than my competitors    during one of the worst recessions in history  end result ...

# %%
from helpers import individualFeatures

text = metadata['content'][0]
words = text.split(' ')
n_trigger_words = individualFeatures().triggerWords(text)
n_words = len(words)
n_words, n_trigger_words
# Out:
# (2787, 89)
