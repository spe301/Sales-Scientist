# %% [markdown]
# # Features needed
#
# ## table 1: main dataset
# We will need the following features from both Facebook and Instagram...
# * number of followers
# * total number of likes
# * number of posts in location + spas (Facebook only)
# * number of posts in hashtag + spa (Instagram only)

# %% [markdown]
# ## tables 2 and 3: Facebook and Instagram seperatley
# * strategy
# * objective
# * engadgement score (calculated based off of data in table 1)
# * sentiment of comments on platform relative to average for spas
# * polarity on comments on platform relative to average for spas
# * average number of comments per post on platform
# * average number of likes per post on platform
# * reach
#
# ## table 4: this data will be collected from here on out
# * conversion rate
# * leads generated
# * CRT
# * RPM (revenue per 1,000 ad impressions)
# * CPM(cost per 1,000 ad impressions)
# * CPA (cost per aquisition)
# * LTV
# * ROAS
# * strategy

# %%
from facebook_scraper import get_posts

# %%
o = {'comments': True, 'reactors': True}
likes = 0
for post in get_posts('AquaVieDaySpaUT', pages=30, extra_info=True, options=o):
    likes += post['likes']
    
likes
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-321c6b8685a5> in <module>
#       1 o = {'comments': True, 'reactors': True}
#       2 likes = 0
# ----> 3 for post in get_posts('AquaVieDaySpaUT', pages=30, extra_info=True, options=o):
#       4     likes += post['likes']
#       5
#
# ~\Anaconda3\lib\site-packages\facebook_scraper\facebook_scraper.py in _generic_get_posts(self, extract_post_fn, iter_pages_fn, page_limit, options, remove_source, **kwargs)
#     383             logger.debug("Extracting posts from page %s", i)
#     384             for post_element in page:
# --> 385                 post = extract_post_fn(post_element, options=options, request_fn=self.get)
#     386                 if remove_source:
#     387                     post.pop('source', None)
#
# ...

# %% [markdown]
# rescources: https://pypi.org/project/facebook-scraper/
