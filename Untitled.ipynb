# %% [markdown]
# trigger words are words that are associated with a call to action. We are creating a list of them so that we can cout the number of trigger words a business has in their landing page. A lot of trigger words indicate multiple CTA's, this is a sign of spending too much on ads.

# %%
import pandas as pd

# %%
class individualFeatures:
    '''def __init__(self, percentSocial, percentAds):
        self.percentSocial = percentSocial
        self.percentAds = percentAds'''
    
    def percentPaidSearch(self, percentSearch, percentPaid):
        return percentSearch * (percentPaid/100)
    
    def adSpend(self, visits, percentSocial, percentAds, percentPaidSearch):
        social = (visits * (percentSocial/100)) * 7
        display = (visits * (percentAds/100)) * 7
        paidSearch = (visits * (percentPaidSearch/100)) * 0.95
        return round(social + display + paidSearch)
    
    def percentAdTraffic(self, percentSocial, percentAds, percentPaidSearch):
        return round(percentSocial+percentAds+percentPaidSearch, 2)
    
class aggregateFeatures:
    triggerWords = ['book', 'call', 'today', 'get', 'my', 'free', 'copy', 'checklist', 
                'pdf', 'report', 'ebook', 'join', 'session', 'now', 'set', 'email',
                'free', 'list', 'attend', 'start', 'access', 'training', 'speak', 
                'expert', 'here']
    
    def adRevenue(self, revenue, percentAdTraffic):
        return revenue * (percentAdTraffic/100)
    
    def roas(self, adRevenue, adSpend):
        return adRevenue - adSpend
    
    def cac(self, newCustomers, adSpend):
        return newCustomers / adSpend
    
    def profit(self, revenue, adSpend, hardcosts):
        return revenue - adSpend - hardcosts
    
    def landingPageComplexity(self, links, words):
        tw = 0
        for w in words:
            if w in self.triggerWords:
                tw += 1
        return tw * len(links) * len(words)
    
    def profitMargin(self, revenue, adSpend, hardcosts):
        af = aggregateFeatures()
        return af.profit(revenue, adSpend, hardcosts) / revenue

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\aacjp\Spencer\datasets\MockHyros.csv').drop(['Unnamed: 0'], axis='columns')

# %%
IF = individualFeatures()
pps = IF.percentPaidSearch(36.35, 3.84)
IF.adSpend(86590, 6.84, 1.57, pps)
# Out:
# 52124

# %%
IF.percentAdTraffic(6.84, 1.57, pps)
# Out:
# 9.81

# %%
df
# Out:
#                                lead  closed  monthly traffic spend  \
# 0                     FrankKern.com       1                52184.0
# 1                  ImpactTheory.Com       1                    NaN
# 2     digitalmillionairesecrets.com       1                    NaN
# 3                    mastermind.com       1                    NaN
# 4                     ShopaNova.com       1                    NaN
# 5                        SamCart.io       1                    NaN
# 6                  Clickfunnels.com       1                    NaN
# 7          billygeneismarketing.com       1                    NaN
# 8                      kinobody.com       1                    NaN
# 9                      Ladyboss.com       1                    NaN
# 10                    GymLaunch.com       1                    NaN
# 11             SmarterNutrition.com       1                    NaN
# 12              thedouglasjames.com       1                    NaN
# 13            fulltimefilmmaker.com       1                    NaN
# 14                 webuildbrands UG       1                    NaN
# 15  leadgenblueprint.ryanwegner.com       1                    NaN
# 16                   groovelife.com       1                    NaN
# 17               NINEUNIVERSITY.COM       1                    NaN
# 18                    peterszabo.co       1                    NaN
# 19                     Current9.com       1                    NaN
# 20                   rydermedia.com       1                    NaN
# 21             prestigepromedia.com       1                    NaN
# 22                     admagnet.com       1                    NaN
# 23                     AdSkills.com       1                    NaN
# 24                 gatestonebpo.com       1                    NaN
# 25                     heybrain.com       1                    NaN
# 26            milliondollarfirms.co       1                    NaN
# 27             rankoneecommerce.com       1                    NaN
# 28                     leadjolt.com       1                    NaN
# 29          InclusivleyCreative.com       1                    NaN
# 30                    neilpatel.com       0                    NaN
# 31                  ImpedeMedia.com       0                    NaN
# 32                 JamesMills.co.uk       0                    NaN
# 33                 exfilproject.com       0                    NaN
# 34                   seo-hacker.com       0                    NaN
# 35                   hautehijab.com       0                    NaN
# 36                    ontraport.com       0                    NaN
# 37               getmainlobster.com       0                    NaN
# 38                 launchtitans.com       0                    NaN
# 39                       eofire.com       0                    NaN
# 40                         reww.com       0                    NaN
# 41                        draxe.com       0                    NaN
# 42                   titansdvds.com       0                    NaN
# 43        vitalitymarketingfirm.com       0                    NaN
# 44                   embertribe.com       0                    NaN
# 45                 theyoungrens.com       0                    NaN
#
#     n paid traffic platforms            domain business model  \
# 0                        5.0  entrepreneurship           info
# 1                        NaN  self-development          media
# 2                        NaN  entrepreneurship           info
# 3                        NaN  entrepreneurship       software
# 4                        NaN         ecommerce       software
# 5                        NaN         ecommerce       software
# 6                        NaN         marketing       software
# 7                        NaN  entrepreneurship           info
# 8                        NaN           fitness           info
# 9                        NaN           fitness           info
# 10                       NaN  entrepreneurship           info
# 11                       NaN           fitness      ecommerce
# 12                       NaN  entrepreneurship           info
# 13                       NaN              film           info
# 14                       NaN         marketing     consulting
# 15                       NaN  entrepreneurship           info
# 16                       NaN           apparel      ecommerce
# 17                       NaN         ecommerce           info
# 18                       NaN  entrepreneurship           info
# 19                       NaN  entrepreneurship           info
# 20                       NaN         marketing     consulting
# 21                       NaN         marketing     consulting
# 22                       NaN         marketing     consulting
# 23                       NaN         marketing     consulting
# 24                       NaN           finance     consulting
# 25                       NaN        technology           info
# 26                       NaN           finance           info
# 27                       NaN          ecomerce       software
# 28                       NaN         marketing     consulting
# 29                       NaN         marketing     consulting
# 30                       NaN         marketing     consulting
# 31                       NaN         marketing     consulting
# 32                       NaN        technology     consulting
# 33                       NaN         marketing     consulting
# 34                       NaN         marketing     consulting
# 35                       NaN           apparel      ecommerce
# 36                       NaN         marketing       software
# 37                       NaN              food     restaurant
# 38                       NaN         marketing     consulting
# 39                       NaN  entrepreneurship           info
# 40                       NaN        realestate     consulting
# 41                       NaN            health           info
# 42                       NaN         marketing     consulting
# 43                       NaN         marketing     consulting
# 44                       NaN         marketing     consulting
# 45                       NaN       photography     consulting
#
#     monthly revenue  % paid traffic  average order value  new customers  ...  \
# 0               NaN            9.81                  NaN            NaN  ...
# 1               NaN             NaN                  NaN            NaN  ...
# 2               NaN             NaN                  NaN            NaN  ...
# 3               NaN             NaN                  NaN            NaN  ...
# 4               NaN             NaN                  NaN            NaN  ...
# 5               NaN             NaN                  NaN            NaN  ...
# 6               NaN             NaN                  NaN            NaN  ...
# 7               NaN             NaN                  NaN            NaN  ...
# 8               NaN             NaN                  NaN            NaN  ...
# 9               NaN             NaN                  NaN            NaN  ...
# 10              NaN             NaN                  NaN            NaN  ...
# 11              NaN             NaN                  NaN            NaN  ...
# 12              NaN             NaN                  NaN            NaN  ...
# 13              NaN             NaN                  NaN            NaN  ...
# 14              NaN             NaN                  NaN            NaN  ...
# 15              NaN             NaN                  NaN            NaN  ...
# 16              NaN             NaN                  NaN            NaN  ...
# 17              NaN             NaN                  NaN            NaN  ...
# 18              NaN             NaN                  NaN            NaN  ...
# 19              NaN             NaN                  NaN            NaN  ...
# 20              NaN             NaN                  NaN            NaN  ...
# 21              NaN             NaN                  NaN            NaN  ...
# 22              NaN             NaN                  NaN            NaN  ...
# 23              NaN             NaN                  NaN            NaN  ...
# 24              NaN             NaN                  NaN            NaN  ...
# 25              NaN             NaN                  NaN            NaN  ...
# 26              NaN             NaN                  NaN            NaN  ...
# 27              NaN             NaN                  NaN            NaN  ...
# 28              NaN             NaN                  NaN            NaN  ...
# 29              NaN             NaN                  NaN            NaN  ...
# 30              NaN             NaN                  NaN            NaN  ...
# 31              NaN             NaN                  NaN            NaN  ...
# 32              NaN             NaN                  NaN            NaN  ...
# 33              NaN             NaN                  NaN            NaN  ...
# 34              NaN             NaN                  NaN            NaN  ...
# 35              NaN             NaN                  NaN            NaN  ...
# 36              NaN             NaN                  NaN            NaN  ...
# 37              NaN             NaN                  NaN            NaN  ...
# 38              NaN             NaN                  NaN            NaN  ...
# 39              NaN             NaN                  NaN            NaN  ...
# 40              NaN             NaN                  NaN            NaN  ...
# 41              NaN             NaN                  NaN            NaN  ...
# 42              NaN             NaN                  NaN            NaN  ...
# 43              NaN             NaN                  NaN            NaN  ...
# 44              NaN             NaN                  NaN            NaN  ...
# 45              NaN             NaN                  NaN            NaN  ...
#
#     ad revenue  roas  cac  profit  keyword matchtype n links lp  n words lp  \
# 0          NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 1          NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 2          NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 3          NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 4          NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 5          NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 6          NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 7          NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 8          NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 9          NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 10         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 11         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 12         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 13         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 14         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 15         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 16         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 17         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 18         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 19         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 20         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 21         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 22         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 23         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 24         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 25         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 26         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 27         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 28         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 29         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 30         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 31         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 32         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 33         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 34         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 35         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 36         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 37         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 38         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 39         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 40         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 41         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 42         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 43         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 44         NaN   NaN  NaN     NaN                NaN        NaN         NaN
# 45         NaN   NaN  NaN     NaN                NaN        NaN         NaN
#
#     trigger words  lp  lpc  profit margin
# 0                 NaN  NaN            NaN
# 1                 NaN  NaN            NaN
# 2                 NaN  NaN            NaN
# 3                 NaN  NaN            NaN
# 4                 NaN  NaN            NaN
# 5                 NaN  NaN            NaN
# 6                 NaN  NaN            NaN
# 7                 NaN  NaN            NaN
# 8                 NaN  NaN            NaN
# 9                 NaN  NaN            NaN
# 10                NaN  NaN            NaN
# 11                NaN  NaN            NaN
# 12                NaN  NaN            NaN
# 13                NaN  NaN            NaN
# 14                NaN  NaN            NaN
# 15                NaN  NaN            NaN
# 16                NaN  NaN            NaN
# 17                NaN  NaN            NaN
# 18                NaN  NaN            NaN
# 19                NaN  NaN            NaN
# 20                NaN  NaN            NaN
# 21                NaN  NaN            NaN
# 22                NaN  NaN            NaN
# 23                NaN  NaN            NaN
# 24                NaN  NaN            NaN
# 25                NaN  NaN            NaN
# 26                NaN  NaN            NaN
# 27                NaN  NaN            NaN
# 28                NaN  NaN            NaN
# 29                NaN  NaN            NaN
# 30                NaN  NaN            NaN
# 31                NaN  NaN            NaN
# 32                NaN  NaN            NaN
# 33                NaN  NaN            NaN
# 34                NaN  NaN            NaN
# 35                NaN  NaN            NaN
# 36                NaN  NaN            NaN
# 37                NaN  NaN            NaN
# 38                NaN  NaN            NaN
# 39                NaN  NaN            NaN
# 40                NaN  NaN            NaN
# 41                NaN  NaN            NaN
# 42                NaN  NaN            NaN
# 43                NaN  NaN            NaN
# 44                NaN  NaN            NaN
# 45                NaN  NaN            NaN
#
# [46 rows x 28 columns]

# %%
#class scraper:
    
def similarWeb(df):
    base_url = 'https://www.similarweb.com/website/{}/'
    leads = list(df['lead'].apply(lambda x: x.lower()))
    url = base_url.format(leads[0])
    return url

# %%
lead = list(df['lead'])[0].lower()

# %%
similarWeb(df)
# Out:
# 'https://www.similarweb.com/website/frankkern.com/'
